# %%
# !python -m ee619.train
# Out:
# pybullet build time: May 27 2021 14:59:23
# /home/jaeyoung/anaconda3/envs/ee619/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# argv[0]=
# argv[0]=
# Ep.: 0, Total Steps: 25, Ep.Steps: 25, Score: 26.935, Avg.Score: 26.935, Max.Score: 26.935, Time: 00:00:00
# Ep.: 1, Total Steps: 33, Ep.Steps: 8, Score: 13.134, Avg.Score: 20.035, Max.Score: 26.935, Time: 00:00:00
# Ep.: 2, Total Steps: 44, Ep.Steps: 11, Score: 15.010, Avg.Score: 18.360, Max.Score: 26.935, Time: 00:00:00
# Ep.: 3, Total Steps: 70, Ep.Steps: 26, Score: 28.400, Avg.Score: 20.870, Max.Score: 28.400, Time: 00:00:00
# Ep.: 4, Total Steps: 84, Ep.Steps: 14, Score: 17.519, Avg.Score: 20.200, Max.Score: 28.400, Time: 00:00:00
# Ep.: 5, Total Steps: 98, Ep.Steps: 14, Score: 16.144, Avg.Score: 19.524, Max.Score: 28.400, Time: 00:00:00
# ...

# %%
# !python -m evaluate
# Out:
# pybullet build time: May 27 2021 14:59:23
# /home/jaeyoung/anaconda3/envs/ee619/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# state_size:  22 , action_size:  6 , action_high:  1.0
# Traceback (most recent call last):
#   File "evaluate.py", line 86, in <module>
#     agent.load('dir_Walker2D_002', 'chpnt_ts2500')
#   File "/home/jaeyoung/ee619/rl_pj1/ee619/agent.py", line 182, in load
#     self.actor.load_state_dict(torch.load(os.path.join(dir,'%s_actor.pth' % prefix)))
#   File "/home/jaeyoung/anaconda3/envs/ee619/lib/python3.8/site-packages/torch/serialization.py", line 581, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/jaeyoung/anaconda3/envs/ee619/lib/python3.8/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
# ...
